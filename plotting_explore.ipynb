# %% [markdown]
# # Plotting Explore

# %%
from plotting_utils import (
    plot_forecast,
    plot_crps_bydate,
    score_improvement_bysite,
    plot_improvement_bysite,
    plot_global_percentages,
    plot_region_percentages,
    plot_site_type_percentages_bymodel,
    plot_site_type_percentages_global,
    plot_window_and_sitetype_performance,
    generate_metadata_df,
    plot_crps_over_time_agg,
)
import pandas as pd

targets = pd.read_csv("targets.csv.gz")
metadata = generate_metadata_df()
# Out:
# /home/rstudio/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
scores_dict = {}
model_names = ["RNN", "TFT", "BlockRNN", "Transformer",
               "NLinear", "DLinear", "NBEATS", "TCN"]
target_variables = ['oxygen', 'temperature', 'chla']

for model in model_names:
    scores_dict[model] = {}
    for target_variable in target_variables:
        scores_dict[model][target_variable] = {}
        for pos in ['inter', 'intra']:
            scores_dict[model][target_variable][pos] = pd.read_csv(
                f'scores/{model}_{target_variable}_{pos}.csv'
            )

# %% [markdown]
# ## Historical Exploration

# %% [markdown]
# ### Chla PRPO Example

# %%
site_id = 'PRPO'
target_variable = 'chla'
plot_crps_bydate(
    f'forecasts/{site_id}/{target_variable}/BlockRNN_default/forecast_*', 
    targets, 
    site_id, 
    target_variable, 
    suffix='default'
)

# %%
plot_forecast(
    '2023_05_16',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
from utils import TimeSeriesPreprocessor
data_preprocessor = TimeSeriesPreprocessor()
site = "PRPO"
data_preprocessor.load(site)
data_preprocessor.plot_by_site(site)

# %% [markdown]
# ### Chla TOMB Explore

# %%
plot_crps_bydate(
    'forecasts/TOMB/chla/BlockRNN_default/forecast_*', 
    targets, 
    'TOMB', 
    'chla', 
    suffix='default'
)

# %%
plot_forecast(
    '2023_06_15',
    targets,
    'TOMB',
    'chla',
    'BlockRNN_default',
)

# %%
plot_forecast(
    '2022_07_20',
    targets,
    'TOMB',
    'chla',
    'BlockRNN_default',
)

# %%
data_preprocessor = TimeSeriesPreprocessor()
site = "TOMB"
data_preprocessor.load(site)
data_preprocessor.plot_by_site(site)

# %% [markdown]
# ### TOMB Temperature

# %%
site_id = 'TOMB'
target_variable = 'temperature'
plot_crps_bydate(
    f'forecasts/{site_id}/{target_variable}/BlockRNN_default/forecast_*', 
    targets, 
    site_id, 
    target_variable, 
    suffix='default'
)

# %%
plot_forecast(
    '2023_01_16',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
plot_forecast(
    '2023_02_15',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
plot_forecast(
    '2022_09_18',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
plot_forecast(
    '2023_03_17',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %% [markdown]
# ## Naive Exploration

# %% [markdown]
# #### PRLA Chla

# %%
plot_crps_bydate(
    'forecasts/PRLA/chla/BlockRNN_default/forecast_*', 
    targets, 
    'PRLA', 
    'chla', 
    suffix='default'
)

# %%
site_id = 'PRLA'
target_variable = 'chla'
plot_forecast(
    '2022_07_20',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'PRLA'
target_variable = 'chla'
plot_forecast(
    '2022_08_19',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'PRLA'
target_variable = 'chla'
plot_forecast(
    '2022_09_18',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'PRLA'
target_variable = 'chla'
plot_forecast(
    '2022_10_18',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'PRLA'
target_variable = 'chla'
plot_forecast(
    '2023_05_16',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'PRLA'
target_variable = 'chla'
plot_forecast(
    '2023_06_15',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %% [markdown]
# #### ARIK Temperature

# %%
plot_crps_bydate(
    'forecasts/ARIK/temperature/BlockRNN_default/forecast_*', 
    targets, 
    'ARIK', 
    'temperature', 
    suffix='default'
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2022_07_20',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2022_10_18',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2022_11_17',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2022_12_17',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2023_01_16',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2023_02_15',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2023_03_17',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2023_04_16',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2023_05_16',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'ARIK'
target_variable = 'temperature'
plot_forecast(
    '2023_06_15',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %% [markdown]
# #### MAYF Temperature

# %%
plot_crps_bydate(
    'forecasts/MAYF/temperature/BlockRNN_default/forecast_*', 
    targets, 
    'MAYF', 
    'temperature', 
    suffix='default'
)

# %%
site_id = 'MAYF'
target_variable = 'temperature'
plot_forecast(
    '2022_07_20',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'MAYF'
target_variable = 'temperature'
plot_forecast(
    '2022_08_19',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'MAYF'
target_variable = 'temperature'
plot_forecast(
    '2022_09_18',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'MAYF'
target_variable = 'temperature'
plot_forecast(
    '2022_10_18',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %%
site_id = 'MAYF'
target_variable = 'temperature'
plot_forecast(
    '2022_11_17',
    targets,
    site_id,
    target_variable,
    'BlockRNN_default',
)

# %% [markdown]
# #### Exploring certain months

# %%
site_ids = ['ARIK', 'BLWA', 'KING', 'FLNT']
target_variable = 'temperature'
for model in model_names:
    for site_id in site_ids:
        print(f'''
plot_forecast(
    "2023_03_17",
    targets,
    "{site_id}",
    target_variable,
    "{model}_default",
)
        ''')
# Out:
# plot_forecast(
#     "2023_03_17",
#     targets,
#     "ARIK",
#     target_variable,
#     "RNN_default",
# )
#
#
# plot_forecast(
#     "2023_03_17",
#     targets,
#     "BLWA",
#     target_variable,
#     "RNN_default",
# )
#
#
# plot_forecast(
#     "2023_03_17",
#     targets,
#     "KING",
#     target_variable,
#     "RNN_default",
# )
#
#
# plot_forecast(
#     "2023_03_17",
#     targets,
#     "FLNT",
#     target_variable,
#     "RNN_default",
# )
#
#
# plot_forecast(
#     "2023_03_17",
#     targets,
#     "ARIK",
#     target_variable,
#     "TFT_default",
# )
#
#
# plot_forecast(
#     "2023_03_17",
#     targets,
#     "BLWA",
#     target_variable,
#     "TFT_default",
# )
#
#
# plot_forecast(
#     "2023_03_17",
#     targets,
#     "KING",
#     target_variable,
#     "TFT_default",
# )
#
#
# plot_forecast(
#     "2023_03_17",
#     targets,
#     "FLNT",
#     target_variable,
#     "TFT_default",
# )
#
#
# plot_forecast(
#     "2023_03_17",
#     targets,
# ...

# %%
plot_forecast(
    "2023_03_17",
    targets,
    "ARIK",
    target_variable,
    "RNN_default",
)

# %%
plot_forecast(
    "2023_03_17",
    targets,
    "BLWA",
    target_variable,
    "RNN_default",
)

# %%
plot_forecast(
    "2023_03_17",
    targets,
    "KING",
    target_variable,
    "RNN_default",
)

# %%
plot_forecast(
    "2023_03_17",
    targets,
    "FLNT",
    target_variable,
    "RNN_default",
)
